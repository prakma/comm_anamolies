# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sx = np.arange(1000)
sy = np.concatenate((np.random.normal(loc=2, scale=.3,size=500), 
                    np.random.normal(loc=6, scale=.3, size=500)))

# k = np.random.normal(loc=3, scale=.4, size=100)

plt.hist(sy, normed=True)
plt.xlim([-5, 10])
plt.show()

# %%
import math
def mexican_hat(t):
    return (1-(t*t)) * math.exp(-(t*t)/2)

hx = np.arange(-5, 5, .1)
# hx

# %%
# hy = (1-(hx*hx)) * math.exp(-(hx*hx)/2)
hy = np.array(map(mexican_hat, hx))

# %%
plt.plot(hx, hy)
plt.show()

# %%
plt.plot(x, 'bo')
plt.plot(sx,sy, 'r+')
plt.show()

# %%
def convolute(signal_data):
    window = np.ones(int(window_size))/float(window_size)
    return np.convolve(data, window, 'same')

gy = np.convolve(sy, hy, 'same')

plt.plot(sx, gy)
plt.show()
